# %%
import numpy as np
import pandas as pd

# %%
df =pd.read_csv("swiggy.csv")
df.head()
# Out:
#   web-scraper-order               web-scraper-start-url  \
# 0     1619670204-12  https://www.swiggy.com/restaurants
# 1     1619670199-10  https://www.swiggy.com/restaurants
# 2      1619670191-7  https://www.swiggy.com/restaurants
# 3      1619670184-4  https://www.swiggy.com/restaurants
# 4      1619670186-5  https://www.swiggy.com/restaurants
#
#                                          restaurants  \
# 0  Heena panchwati sweetDesserts4.0•24 MINS•₹150 ...
# 1  Gangadhar Hotel- Pure VegNorth Indian2.8•30 MI...
# 2  Dosa Plaza (PURE VEG)South Indian, Fast Food3....
# 3  Chennai Dosa PlazaSouth Indian3.8•40 MINS•₹300...
# 4  Newly AddedAnnapurna DivineIndian--•43 MINS•₹4...
#
#                                     restaurants-href  \
# 0  https://www.swiggy.com/restaurants/heena-panch...
# 1  https://www.swiggy.com/restaurants/gangadhar-h...
# 2  https://www.swiggy.com/restaurants/dosa-plaza-...
# 3  https://www.swiggy.com/restaurants/chennai-dos...
# 4  https://www.swiggy.com/restaurants/annapurna-d...
#
#                         name                  cuisine  \
# 0      Heena panchwati sweet                 Desserts
# 1  Gangadhar Hotel- Pure Veg             North Indian
# 2      Dosa Plaza (PURE VEG)  South Indian, Fast Food
# 3         Chennai Dosa Plaza             South Indian
# 4           Annapurna Divine                   Indian
#
#                          place ratings delivery time veg / non-veg  \
# 0       Kankarbagh, Kankarbagh     4.0       24 MINS      Veg Only
# 1    station road, Fraser Road     2.8       31 MINS      Pure Veg
# 2   Gandhi maidan, Fraser Road     3.9       41 MINS      Pure Veg
# 3  Boring Road, Srikrishnapuri     3.8       40 MINS      Pure Veg
# 4     Fraser Road, Fraser Road      --       43 MINS      Veg Only
#
#                                            discounts
# 0  40% off up to ₹80 | Use code SWIGGYITFree deli...
# 1                                                NaN
# 2  30% off up to ₹150 on orders above ₹325 | Use ...
# 3  10% off up to ₹100 on orders above ₹400 | Use ...
# 4                                                NaN

# %%
df.shape
# Out:
# (13, 11)

# %%
df.columns
# Out:
# Index(['web-scraper-order', 'web-scraper-start-url', 'restaurants',
#        'restaurants-href', 'name', 'cuisine', 'place', 'ratings',
#        'delivery time', 'veg / non-veg', 'discounts'],
#       dtype='object')

# %%
df.info
# Out:
# <bound method DataFrame.info of    web-scraper-order               web-scraper-start-url  \
# 0      1619670204-12  https://www.swiggy.com/restaurants
# 1      1619670199-10  https://www.swiggy.com/restaurants
# 2       1619670191-7  https://www.swiggy.com/restaurants
# 3       1619670184-4  https://www.swiggy.com/restaurants
# 4       1619670186-5  https://www.swiggy.com/restaurants
# 5       1619670179-2  https://www.swiggy.com/restaurants
# 6       1619670176-1  https://www.swiggy.com/restaurants
# 7       1619670196-9  https://www.swiggy.com/restaurants
# 8      1619670201-11  https://www.swiggy.com/restaurants
# 9       1619670189-6  https://www.swiggy.com/restaurants
# 10      1619670194-8  https://www.swiggy.com/restaurants
# 11      1619670181-3  https://www.swiggy.com/restaurants
# 12     1619670206-13  https://www.swiggy.com/restaurants
#
#                                           restaurants  \
# 0   Heena panchwati sweetDesserts4.0•24 MINS•₹150 ...
# 1   Gangadhar Hotel- Pure VegNorth Indian2.8•30 MI...
# 2   Dosa Plaza (PURE VEG)South Indian, Fast Food3....
# 3   Chennai Dosa PlazaSouth Indian3.8•40 MINS•₹300...
# 4   Newly AddedAnnapurna DivineIndian--•43 MINS•₹4...
# 5   KHEER MAHALChinese, Indian, Sweets3.9•67 MINS•...
# 6   Chandan DhabaIndian, Fast Food, Tandoor, Birya...
# 7   Desi Tadka Family RestaurantBiryani, Indian, C...
# 8   Zaika Family Fast FoodIndian, Chinese3.5•47 MI...
# 9   Newly AddedAcharPapad RestaurantNorth Indian, ...
# 10  Newly AddedMaa Shitala SweetsSweets--•36 MINS•...
# 11  Cafe Coffee DayBeverages, Snacks, Desserts3.9•...
# 12  PromotedHARILALBakery, Sweets, Indian4.1•34 MI...
#
#                                      restaurants-href  \
# 0   https://www.swiggy.com/restaurants/heena-panch...
# 1   https://www.swiggy.com/restaurants/gangadhar-h...
# 2   https://www.swiggy.com/restaurants/dosa-plaza-...
# 3   https://www.swiggy.com/restaurants/chennai-dos...
# 4   https://www.swiggy.com/restaurants/annapurna-d...
# 5   https://www.swiggy.com/restaurants/kheer-mahal...
# 6   https://www.swiggy.com/restaurants/chandan-dha...
# 7   https://www.swiggy.com/restaurants/desi-tadka-...
# 8   https://www.swiggy.com/restaurants/zaika-famil...
# 9   https://www.swiggy.com/restaurants/acharpapad-...
# 10  https://www.swiggy.com/restaurants/maa-shitala...
# 11  https://www.swiggy.com/restaurants/cafe-coffee...
# 12  https://www.swiggy.com/restaurants/harilal-kan...
#
#                             name  \
# 0          Heena panchwati sweet
# 1      Gangadhar Hotel- Pure Veg
# 2          Dosa Plaza (PURE VEG)
# 3             Chennai Dosa Plaza
# 4               Annapurna Divine
# 5                    KHEER MAHAL
# 6                  Chandan Dhaba
# 7   Desi Tadka Family Restaurant
# 8         Zaika Family Fast Food
# 9          AcharPapad Restaurant
# 10            Maa Shitala Sweets
# 11               Cafe Coffee Day
# 12                       HARILAL
#
#                                               cuisine  \
# 0                                            Desserts
# 1                                        North Indian
# 2                             South Indian, Fast Food
# 3                                        South Indian
# 4                                              Indian
# 5                             Chinese, Indian, Sweets
# 6                 Indian, Fast Food, Tandoor, Biryani
# 7                            Biryani, Indian, Chinese
# 8                                     Indian, Chinese
# 9   North Indian, Chinese, Fast Food, Beverages, T...
# 10                                             Sweets
# 11                        Beverages, Snacks, Desserts
# 12                             Bakery, Sweets, Indian
#
#                                                 place ratings delivery time  \
# 0                              Kankarbagh, Kankarbagh     4.0       24 MINS
# 1                           station road, Fraser Road     2.8       31 MINS
# 2                          Gandhi maidan, Fraser Road     3.9       41 MINS
# 3                         Boring Road, Srikrishnapuri     3.8       40 MINS
# 4                            Fraser Road, Fraser Road      --       43 MINS
# 5                                  Khajpura, Khajpura     3.9       67 MINS
# 6                                  Khajpura, Khajpura     3.6       68 MINS
# 7                            Fraser Road, Fraser Road      --       35 MINS
# 8                           Hanuman nagar, Kankarbagh     3.5       47 MINS
# 9                            Fraser Road, Fraser Road      --       41 MINS
# 10                             Kankarbagh, Kankarbagh      --       36 MINS
# 11  REGENT THEATRE -PATNA, Fraser Road | Change Ou...     3.9       56 MINS
# 12                             Kankarbagh, Kankarbagh     4.1       34 MINS
#
#    veg / non-veg                                          discounts
# 0       Veg Only  40% off up to ₹80 | Use code SWIGGYITFree deli...
# 1       Pure Veg                                                NaN
# 2       Pure Veg  30% off up to ₹150 on orders above ₹325 | Use ...
# 3       Pure Veg  10% off up to ₹100 on orders above ₹400 | Use ...
# 4       Veg Only                                                NaN
# 5       Pure Veg  25% off | Use code UNLIMITED30% off up to ₹75 ...
# 6       Veg Only  50% off | Use code UNLIMITED50% off up to ₹100...
# 7       Veg Only  20% off up to ₹100 on orders above ₹400 | Use ...
# 8       Veg Only  40% off | Use code UNLIMITED50% off up to ₹100...
# 9       Pure Veg            40% off on orders above ₹149 up to ₹100
# 10      Veg Only              30% off up to ₹75 | Use code SWIGGYIT
# 11      Veg Only  30% off | Use code UNLIMITED50% off up to ₹100...
# 12      Pure Veg                       10% off | Use code UNLIMITED  >

# %%
df.describe()
# Out:
#        web-scraper-order               web-scraper-start-url  \
# count                 13                                  13
# unique                13                                   1
# top        1619670204-12  https://www.swiggy.com/restaurants
# freq                   1                                  13
#
#                                               restaurants  \
# count                                                  13
# unique                                                 13
# top     Heena panchwati sweetDesserts4.0•24 MINS•₹150 ...
# freq                                                    1
#
#                                          restaurants-href  \
# count                                                  13
# unique                                                 13
# top     https://www.swiggy.com/restaurants/heena-panch...
# freq                                                    1
#
#                          name   cuisine                   place ratings  \
# count                      13        13                      13      13
# unique                     13        13                       8       8
# top     Heena panchwati sweet  Desserts  Kankarbagh, Kankarbagh      --
# freq                        1         1                       3       4
#
#        delivery time veg / non-veg  \
# count             13            13
# unique            12             2
# top          41 MINS      Veg Only
# freq               2             7
#
#                                                 discounts
# count                                                  11
# unique                                                 11
# top     40% off up to ₹80 | Use code SWIGGYITFree deli...
# freq                                                    1

# %%
df.restaurants.unique()
# Out:
# array(['Heena panchwati sweetDesserts4.0•24 MINS•₹150 FOR TWO40% off | Use SWIGGYITQuick View',
#        'Gangadhar Hotel- Pure VegNorth Indian2.8•30 MINS•₹150 FOR TWOQuick View',
#        'Dosa Plaza (PURE VEG)South Indian, Fast Food3.9•40 MINS•₹199 FOR TWO30% off | Use SWIGGYITQuick View',
#        'Chennai Dosa PlazaSouth Indian3.8•40 MINS•₹300 FOR TWO10% off | Use JUMBOQuick View',
#        'Newly AddedAnnapurna DivineIndian--•43 MINS•₹400 FOR TWOQuick View',
#        'KHEER MAHALChinese, Indian, Sweets3.9•67 MINS•₹150 FOR TWO30% off | Use SWIGGYITQuick View',
#        'Chandan DhabaIndian, Fast Food, Tandoor, Biryani3.6•68 MINS•₹150 FOR TWO50% off | Use SWIGGYITQuick View',
#        'Desi Tadka Family RestaurantBiryani, Indian, Chinese--•33 MINS•₹250 FOR TWO20% off | Use SWIGGYITQuick View',
#        'Zaika Family Fast FoodIndian, Chinese3.5•47 MINS•₹200 FOR TWO50% off | Use SWIGGYITQuick View',
#        'Newly AddedAcharPapad RestaurantNorth Indian, Chinese, Fast Food, Beverages, Thalis--•38 MINS•₹400 FOR TWO40% off on orders above ₹149Quick View',
#        'Newly AddedMaa Shitala SweetsSweets--•36 MINS•₹100 FOR TWO30% off | Use SWIGGYITQuick View',
#        'Cafe Coffee DayBeverages, Snacks, Desserts3.9•54 MINS•₹300 FOR TWO50% off | Use SWIGGYITQuick View',
#        'PromotedHARILALBakery, Sweets, Indian4.1•34 MINS•₹150 FOR TWO10% off | Use UNLIMITEDQuick View'],
#       dtype=object)

# %%
df.isnull().sum()
# Out:
# web-scraper-order        0
# web-scraper-start-url    0
# restaurants              0
# restaurants-href         0
# name                     0
# cuisine                  0
# place                    0
# ratings                  0
# delivery time            0
# veg / non-veg            0
# discounts                2
# dtype: int64

# %%
df.columns
# Out:
# Index(['web-scraper-order', 'web-scraper-start-url', 'restaurants',
#        'restaurants-href', 'name', 'cuisine', 'place', 'ratings',
#        'delivery time', 'veg / non-veg', 'discounts'],
#       dtype='object')

# %%
x=df[['name','cuisine','restaurants']]
x.columns
# Out:
# Index(['name', 'cuisine', 'restaurants'], dtype='object')

# %%
x.shape
# Out:
# (13, 3)

# %%
x.head()
# Out:
#                         name                  cuisine  \
# 0      Heena panchwati sweet                 Desserts
# 1  Gangadhar Hotel- Pure Veg             North Indian
# 2      Dosa Plaza (PURE VEG)  South Indian, Fast Food
# 3         Chennai Dosa Plaza             South Indian
# 4           Annapurna Divine                   Indian
#
#                                          restaurants
# 0  Heena panchwati sweetDesserts4.0•24 MINS•₹150 ...
# 1  Gangadhar Hotel- Pure VegNorth Indian2.8•30 MI...
# 2  Dosa Plaza (PURE VEG)South Indian, Fast Food3....
# 3  Chennai Dosa PlazaSouth Indian3.8•40 MINS•₹300...
# 4  Newly AddedAnnapurna DivineIndian--•43 MINS•₹4...

# %%
from sklearn.preprocessing import LabelEncoder
lel = LabelEncoder()
x["restaurants"]=lel.fit_transform(x["restaurants"])
x.head()
# Out:
# C:\Users\REALIN~1\AppData\Local\Temp/ipykernel_18416/378040770.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x["restaurants"]=lel.fit_transform(x["restaurants"])
#                         name                  cuisine  restaurants
# 0      Heena panchwati sweet                 Desserts            6
# 1  Gangadhar Hotel- Pure Veg             North Indian            5
# 2      Dosa Plaza (PURE VEG)  South Indian, Fast Food            4
# 3         Chennai Dosa Plaza             South Indian            2
# 4           Annapurna Divine                   Indian            9

# %%
x.head(30)
# Out:
#                             name  \
# 0          Heena panchwati sweet
# 1      Gangadhar Hotel- Pure Veg
# 2          Dosa Plaza (PURE VEG)
# 3             Chennai Dosa Plaza
# 4               Annapurna Divine
# 5                    KHEER MAHAL
# 6                  Chandan Dhaba
# 7   Desi Tadka Family Restaurant
# 8         Zaika Family Fast Food
# 9          AcharPapad Restaurant
# 10            Maa Shitala Sweets
# 11               Cafe Coffee Day
# 12                       HARILAL
#
#                                               cuisine  restaurants
# 0                                            Desserts            6
# 1                                        North Indian            5
# 2                             South Indian, Fast Food            4
# 3                                        South Indian            2
# 4                                              Indian            9
# 5                             Chinese, Indian, Sweets            7
# 6                 Indian, Fast Food, Tandoor, Biryani            1
# 7                            Biryani, Indian, Chinese            3
# 8                                     Indian, Chinese           12
# 9   North Indian, Chinese, Fast Food, Beverages, T...            8
# 10                                             Sweets           10
# 11                        Beverages, Snacks, Desserts            0
# 12                             Bakery, Sweets, Indian           11

# %%
from sklearn.model_selection import train_test_split
xtr,xts = train_test_split(x,test_size=0.2)
print(x.shape)
print(xtr.shape)
print(xts.shape)
# Out:
# (13, 3)
# (10, 3)
# (3, 3)
